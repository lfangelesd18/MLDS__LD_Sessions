# %%
#Importando las librerias necesarias
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('C:\\Users\\LANGELES\\Documents\\Personal\\Machine Learning y Data Science\\ML Session\\MLDS__LD_Sessions\\Datasets\\COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries.csv')
dataset
# Out:
#       state                    date  critical_staffing_shortage_today_yes  \
# 0        OH  02/22/2021 12:00:00 AM                                    13
# 1        PR  02/16/2021 12:00:00 AM                                     1
# 2        RI  02/10/2021 12:00:00 AM                                     4
# 3        PR  01/30/2021 12:00:00 AM                                     0
# 4        ND  01/28/2021 12:00:00 AM                                    19
# ...     ...                     ...                                   ...
# 62959    LA  12/21/2021 12:00:00 AM                                    55
# 62960    TN  01/12/2022 12:00:00 AM                                    33
# 62961    IL  01/04/2022 12:00:00 AM                                    13
# 62962    OH  12/27/2021 12:00:00 AM                                    37
# 62963    AR  01/12/2022 12:00:00 AM                                    17
#
#        critical_staffing_shortage_today_no  \
# ...

# %%
#Convirtiendo a datetime
dataset['date']=pd.to_datetime(dataset['date'])
dataset['date']
# Out:
# 0       2021-02-22
# 1       2021-02-16
# 2       2021-02-10
# 3       2021-01-30
# 4       2021-01-28
#            ...
# 62959   2021-12-21
# 62960   2022-01-12
# 62961   2022-01-04
# 62962   2021-12-27
# 62963   2022-01-12
# Name: date, Length: 62964, dtype: datetime64[ns]

# %%
#Buscando filas con datos faltantes
nan_count = dataset.isna().sum()
nan_count
#Total de records con valores faltantes:
nan_count_total = dataset.isna().sum().sum()
nan_count_total
# Out:
# 750080

# %%
#Lidiando con los valores faltantes
#total_records_inicial = dataset.length()
#dataset = dataset.dropna()
#total_records_final = dataset.length()

# %%
dataset
# Out:
# Empty DataFrame
# ...
